# %% [markdown]
# # Helthcare Dataset

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('data/healthcare_dataset.csv')
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
# Retrieve the duration of stay in a hospital
for date in ['Date of Admission', 'Discharge Date']:
    df[date] = pd.to_datetime(df[date])

df['days'] = df['Discharge Date'] - df['Date of Admission']
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
# Modify the format of the duration of stay
df['days'] = df['days'].astype('str').str.extract(r"(\d+)").astype(int)
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %% [markdown]
# ### Drop variables

# %%
cols = ['Date of Admission', 'Doctor', 'Room Number', 'Name', 'Discharge Date']
df.drop(cols, axis=1, inplace=True)
df.head()
# Out:
#    Age  Gender Blood Type Medical Condition                   Hospital  \
# 0   81  Female         O-          Diabetes           Wallace-Hamilton
# 1   35    Male         O+            Asthma  Burke, Griffin and Cooper
# 2   61    Male         B-           Obesity                 Walton LLC
# 3   49    Male         B-            Asthma                 Garcia Ltd
# 4   51    Male         O-         Arthritis    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount Admission Type   Medication  \
# 0           Medicare    37490.983364       Elective      Aspirin
# 1   UnitedHealthcare    47304.064845      Emergency      Lipitor
# 2           Medicare    36874.896997      Emergency      Lipitor
# 3           Medicare    23303.322092         Urgent   Penicillin
# 4   UnitedHealthcare    18086.344184         Urgent  Paracetamol
#
#    Test Results  days
# 0  Inconclusive    14
# 1        Normal    14
# 2        Normal    30
# 3      Abnormal     1
# 4        Normal    24

# %% [markdown]
# ### Data visualization

# %%
df.hist(bins=30, figsize=(12, 8))
plt.show()

# %%
numeric_cols = ['Age', 'Billing Amount', 'days']
non_numeric_cols = ['Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider',
                    'Admission Type', 'Medication', 'Test Results']

# %%
for col in numeric_cols:
    sns.displot(df[col], kde=True, bins='auto', label=col)

plt.show()

# %%
for col in non_numeric_cols:
    df[col].value_counts().plot(kind='bar')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
for col in non_numeric_cols:
    for n_col in numeric_cols:
        plt.figure(figsize=(12, 8))
        sns.boxplot(x=col, y=n_col, data=df)
        plt.title(f'{col} vs {n_col}')
        plt.show()
